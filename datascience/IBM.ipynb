# %% [markdown]
# # IBM Project - Begginer Project

# %% [markdown]
# ## Initial Ingestion

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
#Base 
BASE = '../Data/employee_attrition.csv'

df = pd.read_csv(BASE)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
with pd.option_context("float_format","{:.2f}".format,"display.max_columns",None):
    display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# ...

# %%
df.describe(exclude='number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.nunique()#.where(lambda x: x==1)
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.value_counts()
# Out:
# Age  Attrition  BusinessTravel  DailyRate  Department              DistanceFromHome  Education  EducationField    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  JobRole                JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df["Gender"].value_counts(normalize=True).mul(100).round(2)
# Out:
# Gender
# Male      60.0
# Female    40.0
# Name: proportion, dtype: float64

# %%
top_ten_oldest = df.sort_values(by=['Age','YearsAtCompany'], ascending=False).head(10).reset_index(drop=True)
top_ten_oldest
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   60        No      Travel_Rarely        422  Research & Development
# 1   60        No  Travel_Frequently       1499                   Sales
# 2   60        No      Travel_Rarely        696                   Sales
# 3   60        No      Travel_Rarely       1179                   Sales
# 4   60        No      Travel_Rarely        370  Research & Development
# 5   59        No      Travel_Rarely       1435                   Sales
# 6   59        No      Travel_Rarely       1429  Research & Development
# 7   59        No      Travel_Rarely       1089                   Sales
# 8   59        No      Travel_Rarely        326                   Sales
# 9   59        No      Travel_Rarely        715  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 7          3     Life Sciences              1
# ...

# %%
df[df['Age'] == df['Age'].max()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 411                  7          3  Life Sciences              1
# 427                 28          3      Marketing              1
# 536                 16          4      Marketing              1
# 879                  7          4      Marketing              1
# 1209                 1          4        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
df.nlargest(10, 'Age')
df.nsmallest(10, 'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 296                  3          3  Life Sciences              1
# ...

# %%
top_ten_youngest = df.sort_values(by=['Age','YearsAtCompany'], ascending=True).head(10).reset_index(drop=True)
top_ten_youngest
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   18       Yes      Travel_Rarely        230  Research & Development
# 1   18        No      Travel_Rarely        812                   Sales
# 2   18       Yes  Travel_Frequently       1306                   Sales
# 3   18        No         Non-Travel        287  Research & Development
# 4   18       Yes         Non-Travel        247  Research & Development
# 5   18        No         Non-Travel       1124  Research & Development
# 6   18       Yes  Travel_Frequently        544                   Sales
# 7   18        No         Non-Travel       1431  Research & Development
# 8   19       Yes      Travel_Rarely        528                   Sales
# 9   19       Yes  Travel_Frequently        602                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 3          3     Life Sciences              1
# ...

# %%
df.sort_values(by='YearsAtCompany', ascending=False).head(10).reset_index(drop=True)
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   58       Yes  Travel_Rarely        147  Research & Development
# 1   58        No  Travel_Rarely        682                   Sales
# 2   55        No  Travel_Rarely        685                   Sales
# 3   55        No  Travel_Rarely        452  Research & Development
# 4   52        No  Travel_Rarely        621                   Sales
# 5   55        No     Non-Travel        177  Research & Development
# 6   53       Yes  Travel_Rarely        607  Research & Development
# 7   51        No  Travel_Rarely        770         Human Resources
# 8   52        No     Non-Travel        771                   Sales
# 9   52        No  Travel_Rarely        699  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                23          4           Medical              1
# 1                10          4           Medical              1
# ...

# %%
df.sort_values(by='YearsAtCompany', ascending=True).head(10).reset_index(drop=True)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   21        No      Travel_Rarely        391  Research & Development
# 1   45        No      Travel_Rarely        193  Research & Development
# 2   24       Yes  Travel_Frequently        381  Research & Development
# 3   47        No  Travel_Frequently       1309                   Sales
# 4   37       Yes      Travel_Rarely       1373  Research & Development
# 5   34        No      Travel_Rarely        167  Research & Development
# 6   48        No      Travel_Rarely        530                   Sales
# 7   44        No         Non-Travel        111  Research & Development
# 8   30        No      Travel_Rarely        946  Research & Development
# 9   38        No      Travel_Rarely       1495  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                15          2  Life Sciences              1              30
# ...

# %%
df.sort_values(by='YearsSinceLastPromotion', ascending=False).head(10).reset_index(drop=True)
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   56        No  Travel_Rarely       1369  Research & Development
# 2   46        No  Travel_Rarely       1402                   Sales
# 3   41       Yes  Travel_Rarely       1360  Research & Development
# 4   52        No     Non-Travel        771                   Sales
# 5   39        No  Travel_Rarely        412  Research & Development
# 6   43        No  Travel_Rarely        531                   Sales
# 7   55        No     Non-Travel        177  Research & Development
# 8   53        No  Travel_Rarely       1376                   Sales
# 9   46        No  Travel_Rarely        526                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                23          3     Life Sciences              1
# ...

# %% [markdown]
# ## Data Cleaning, If needed

# %%
#Removing also the employee number, because is the unique identifier, not relevant for the analyis. The other 3 columsn have only one value.
# df = df.drop(['EmployeeCount','StandardHours','Over18','EmployeeNumber'],axis=1) #axis=1 is the default value, this is an other way to do it.
df = df.drop(columns=['EmployeeCount','StandardHours','Over18','EmployeeNumber'])
df.shape
# Out:
# (1470, 31)

# %% [markdown]
# ## Groupping Exploration

# %%
df.groupby(['Department','Attrition']).size()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
df.pivot_table(
    index= 'Department',
    columns='Attrition',
    aggfunc='size',
)
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
df.groupby(['Department','Attrition'])['MonthlyIncome'].mean()
# Out:
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby(['Gender'])['Department'].count()
# Out:
# Gender
# Female    588
# Male      882
# Name: Department, dtype: int64

# %%
df.groupby(['Gender'])['JobLevel'].value_counts().sort_index(ascending=False)
# Out:
# Gender  JobLevel
# Male    5            45
#         4            55
#         3           124
#         2           314
#         1           344
# Female  5            24
#         4            51
#         3            94
#         2           220
#         1           199
# Name: count, dtype: int64

# %%
df.groupby(['Gender','JobLevel'])['MonthlyIncome'].mean().sort_index(ascending=False)
# Out:
# Gender  JobLevel
# Male    5           19224.844444
#         4           15570.927273
#         3            9706.991935
#         2            5549.184713
#         1            2790.633721
# Female  5           19129.916667
#         4           15431.372549
#         3            9962.702128
#         2            5435.327273
#         1            2780.487437
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ## Segregation in Different Columns Types

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
non_ordered_categorical_Columns = [
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime'
]

ordered_categorical_columns = [
    'Education',
    'EnvironmentSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'JobSatisfaction',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance'
]

target_columns = [
    'Attrition'
]

numerical_columns = [column for column in df.columns if column not in (non_ordered_categorical_Columns + ordered_categorical_columns + target_columns)]

# %%
numerical_columns
# Out:
# [['Age',
#   'DailyRate',
#   'DistanceFromHome',
#   'HourlyRate',
#   'MonthlyIncome',
#   'MonthlyRate',
#   'NumCompaniesWorked',
#   'PercentSalaryHike',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager']]

# %%
for column in (non_ordered_categorical_Columns + ordered_categorical_columns):
    print(f"{column} : {df[column].unique()}")
# Out:
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department : ['Sales' 'Research & Development' 'Human Resources']
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender : ['Female' 'Male']
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus : ['Single' 'Married' 'Divorced']
# OverTime : ['Yes' 'No']
# Education : [2 1 4 3 5]
# EnvironmentSatisfaction : [2 3 4 1]
# JobInvolvement : [3 2 4 1]
# JobLevel : [2 1 3 4 5]
# JobSatisfaction : [4 2 3 1]
# PerformanceRating : [3 4]
# RelationshipSatisfaction : [1 4 2 3]
# StockOptionLevel : [0 1 3 2]
# WorkLifeBalance : [1 3 2 4]

# %%
for column in non_ordered_categorical_Columns:
    df[column] = df[column].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
for column in df.select_dtypes(include ='category'):
    print(f"{column}")
    print(f"{column}.cat.categories: {df[column].cat.categories}") 
    print(f"{column}.cat.ordered: {df[column].cat.ordered}")
    print(f"{column}.cat.codes: {df[column].cat.codes.unique()}")
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
# ...

# %%
df['Attrition'].value_counts().plot(kind='bar', color=['green','red']);

# %%
df['Department'].value_counts().plot(kind='bar');

# %%
pd.crosstab(df['Department'],df['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
#pd.crosstab(df['Department'],df['Attrition'], normalize='columns').style.background_gradient(cmap='coolwarm', axis='columns')#normalize='index' or 'columns'

# %%
df.pivot_table(
    index=['JobRole','JobLevel'],
    columns="Attrition",
    values="MonthlyIncome",
    aggfunc=["mean","size"]
)
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1274878560.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1274878560.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
##This drop any rows that have nan
df.pivot_table(
    index=['JobRole','JobLevel'],
    columns="Attrition",
    values="MonthlyIncome",
    aggfunc=["mean","size"]
).dropna()
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\531153328.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\531153328.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
df.pivot_table(
    index=['JobRole','JobLevel'],
    columns="Attrition",
    values="MonthlyIncome",
    aggfunc=["mean","size"]
).dropna(how="all", subset=[("mean","No"),("mean","Yes")]) # In this case mean yeas is not 100% necessary, because at the no, all values are filled
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1960465721.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1960465721.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# ...

# %%
df.pivot_table(
    index=["Department","Gender"],
    columns="Attrition",
    aggfunc="size"
).unstack("Gender")
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1304347520.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(
# Attrition                  No         Yes
# Gender                 Female Male Female Male
# Department
# Human Resources            14   37      6    6
# Research & Development    336  492     43   90
# Sales                     151  203     38   54

# %% [markdown]
# ## Mapping Table

# %%
#Ideally I want to show the education, not only de indexes
df.groupby("Education")["MonthlyIncome"].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
educational_mapping = {
    1:"Bellow College",
    2:"College",
    3:"Bachelor",
    4:"Master",
    5:"PhD"
}

# %%
df.groupby("Education")["MonthlyIncome"].mean().rename(index=educational_mapping)
# Out:
# Education
# Bellow College    5640.570588
# College           6226.645390
# Bachelor          6517.263986
# Master            6832.402010
# PhD               8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Education")["MonthlyIncome"].size().rename(index=educational_mapping)
# Out:
# Education
# Bellow College    170
# College           282
# Bachelor          572
# Master            398
# PhD                48
# Name: MonthlyIncome, dtype: int64

# %%
pd.crosstab(
    df["Education"], df["JobRole"],
    margins=True,
    margins_name="Total",
    normalize="index"
).rename(index=educational_mapping)
# Out:
# JobRole         Healthcare Representative  Human Resources  \
# Education
# Bellow College                   0.088235         0.029412
# College                          0.074468         0.042553
# Bachelor                         0.083916         0.038462
# Master                           0.110553         0.025126
# PhD                              0.062500         0.062500
# Total                            0.089116         0.035374
#
# JobRole         Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Bellow College               0.205882  0.052941                0.088235
# College                      0.202128  0.067376                0.117021
# Bachelor                     0.181818  0.069930                0.094406
# Master                       0.145729  0.072864                0.095477
# PhD                          0.104167  0.104167                0.104167
# Total                        0.176190  0.069388                0.098639
#
# ...

# %% [markdown]
# ## Charts

# %%
df.groupby("Gender")["Age"].plot(kind="hist", legend=True, alpha = 0.9)
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1227268725.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Gender")["Age"].plot(kind="hist", legend=True, alpha = 0.9)
# Gender
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
df.hist(column="Age",by="Gender", layout=(2,1), figsize=(5,7))
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1688531762.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist(column="Age",by="Gender", layout=(2,1), figsize=(5,7))
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
age_bin = [0, 20, 30, 50, float("inf")]
label = ["Adolescente", "Jovem Adulto", "Adulto Medio", "Adulto Senior"]

df["Age_Name"] = pd.cut(df["Age"], bins=age_bin, labels=label)

df[["Age","Age_Name"]].head(20)
# Out:
#     Age       Age_Name
# 0    41   Adulto Medio
# 1    49   Adulto Medio
# 2    37   Adulto Medio
# 3    33   Adulto Medio
# 4    27   Jovem Adulto
# 5    32   Adulto Medio
# 6    59  Adulto Senior
# 7    30   Jovem Adulto
# 8    38   Adulto Medio
# 9    36   Adulto Medio
# 10   35   Adulto Medio
# 11   29   Jovem Adulto
# 12   31   Adulto Medio
# 13   34   Adulto Medio
# 14   28   Jovem Adulto
# 15   29   Jovem Adulto
# 16   32   Adulto Medio
# 17   22   Jovem Adulto
# 18   53  Adulto Senior
# 19   38   Adulto Medio

# %%
for column in df.select_dtypes("category"):
    print(f"Coluna: {column}")
    print(df[column].cat.categories)
    print(df[column].cat.ordered)
    print(df[column].cat.codes.unique())
# Out:
# Coluna: BusinessTravel
# Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# False
# [2 1 0]
# Coluna: Department
# Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# False
# [2 1 0]
# Coluna: EducationField
# Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# False
# [1 4 3 2 5 0]
# Coluna: Gender
# Index(['Female', 'Male'], dtype='object')
# False
# [0 1]
# Coluna: JobRole
# Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# False
# [7 6 2 4 0 3 8 5 1]
# Coluna: MaritalStatus
# Index(['Divorced', 'Married', 'Single'], dtype='object')
# False
# [2 1 0]
# Coluna: OverTime
# Index(['No', 'Yes'], dtype='object')
# False
# [1 0]
# Coluna: Age_Name
# ...

# %%
#This order the columns based on the "Categorical Value Order "
df["Age_Name"].value_counts().sort_index()
# Out:
# Age_Name
# Adolescente       28
# Jovem Adulto     358
# Adulto Medio     941
# Adulto Senior    143
# Name: count, dtype: int64

# %%
df["Age_Name"].value_counts().sort_index().plot(kind='bar');

# %%
df.groupby(["Age_Name","Attrition"])["Attrition"].size().unstack("Attrition").plot(kind='bar')
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\1972095592.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["Age_Name","Attrition"])["Attrition"].size().unstack("Attrition").plot(kind='bar')
# <Axes: xlabel='Age_Name'>

# %%
pd.crosstab(df["Age_Name"], df["Attrition"], normalize=True).mul(100).round(2).plot(kind='bar')
# Out:
# <Axes: xlabel='Age_Name'>

# %%
ordered_categorical_columns.append('Age_Name')

# %%
ordered_categorical_columns
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'WorkLifeBalance',
#  'Age_Name']

# %%
df[numerical_columns].hist(figsize=(20,12))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'HourlyRate'}>],
#        [<Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>],
#        [<Axes: title={'center': 'TotalWorkingYears'}>,
#         <Axes: title={'center': 'TrainingTimesLastYear'}>,
#         <Axes: title={'center': 'YearsAtCompany'}>,
#         <Axes: title={'center': 'YearsInCurrentRole'}>],
#        [<Axes: title={'center': 'YearsSinceLastPromotion'}>,
#         <Axes: title={'center': 'YearsWithCurrManager'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
df["DistanceFromHome"].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column="DistanceFromHome", vert=False, grid=False, showmeans=True)
# Out:
# <Axes: >

# %%
df.groupby(["Gender","Attrition"])["Age"].describe()
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_19312\851089815.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["Gender","Attrition"])["Age"].describe()
#                   count       mean       std   min   25%   50%    75%   max
# Gender Attrition
# Female No         501.0  38.155689  9.001762  18.0  31.0  37.0  45.00  60.0
#        Yes         87.0  32.574713  9.385333  18.0  27.0  31.0  36.50  58.0
# Male   No         732.0  37.154372  8.792917  18.0  31.0  36.0  43.00  60.0
#        Yes        150.0  34.206667  9.842584  18.0  28.0  32.0  39.75  58.0

# %%
df.boxplot(column="Age", by=["Gender","Attrition"], grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='[Gender, Attrition]'>

# %%
df.boxplot(column="Age", by="JobLevel", grid= False, showmeans=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='JobLevel'>
