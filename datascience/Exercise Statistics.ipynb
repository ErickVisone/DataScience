# %% [markdown]
# ## Exercise 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from auxiliary import *

# %%
data = "../Data/data_statistics/acao.csv"

df = pd.read_csv(data)
df.head()
# Out:
#    preco
# 0   18.7
# 1   18.3
# 2   18.4
# 3   18.7
# 4   18.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   preco   20 non-null     float64
# dtypes: float64(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#            preco
# count  20.000000
# mean   18.475000
# std     0.632352
# min    16.900000
# 25%    18.175000
# 50%    18.500000
# 75%    18.800000
# max    19.900000

# %%
composition_hist_box(df, 'preco')

# %%
df.skew()
# Out:
# preco   -0.364691
# dtype: float64

# %%
df.kurtosis()
# Out:
# preco    1.752875
# dtype: float64

# %% [markdown]
# ## Exercise 2

# %%
data = "../Data/data_statistics/prices.csv"

df_phone = pd.read_csv(data)
df.head()
# Out:
#    preco
# 0   18.7
# 1   18.3
# 2   18.4
# 3   18.7
# 4   18.8

# %%
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   100 non-null    float64
# dtypes: float64(1)
# memory usage: 932.0 bytes

# %%
df_phone.describe()
# Out:
#             Price
# count  100.000000
# mean   190.770000
# std     15.621052
# min    149.000000
# 25%    179.000000
# 50%    189.000000
# 75%    199.000000
# max    239.000000

# %%
composition_hist_box(df_phone, 'Price')

# %%
df_phone.skew()
# Out:
# Price    0.089906
# dtype: float64

# %%
df_phone.kurtosis()
# Out:
# Price    0.669453
# dtype: float64

# %%
df_phone.mode()
# Out:
#    Price
# 0  199.0

# %%
df_phone['Price'].value_counts()
# Out:
# Price
# 199.0    21
# 189.0    19
# 179.0    13
# 169.0     7
# 209.0     6
# 195.0     6
# 205.0     4
# 159.0     3
# 170.0     2
# 185.0     2
# 175.0     2
# 229.0     2
# 215.0     2
# 197.0     1
# 202.0     1
# 219.0     1
# 149.0     1
# 206.0     1
# 183.0     1
# 190.0     1
# 165.0     1
# 196.0     1
# 182.0     1
# 239.0     1
# Name: count, dtype: int64
