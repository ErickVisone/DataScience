# %% [markdown]
# # Pandas Basics

# %% [markdown]
# ## Importing Libraries/Dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
BASE = "../Data/Cereal.csv"

df = pd.read_csv(BASE)

# %%
#Test import
df.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813

# %% [markdown]
# ## Basic Data Exporation

# %%
#Give me the dimension of the dataframe, this case is 77 rows and 16 columns.
df.shape
# Out:
# (77, 16)

# %%
#Contains nbr of rows, data types, how many nulls and the numbers of floats, objects, etc...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
#Alhough I could see in the code above, using the below to check if there is any null info.
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
#Give me basic statistics of the dataframe, based on the numeric columns
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
#Give me the same status but only for categorical columns.
df.describe(exclude='number')
# Out:
#              name mfr type
# count          77  77   77
# unique         77   7    2
# top     100% Bran   K    C
# freq            1  23   74

# %%
#Get only specific data types
df.select_dtypes('object')
# Out:
#                          name mfr type
# 0                   100% Bran   N    C
# 1           100% Natural Bran   Q    C
# 2                    All-Bran   K    C
# 3   All-Bran with Extra Fiber   K    C
# 4              Almond Delight   R    C
# ..                        ...  ..  ...
# 72                    Triples   G    C
# 73                       Trix   G    C
# 74                 Wheat Chex   R    C
# 75                   Wheaties   G    C
# 76        Wheaties Honey Gold   G    C
#
# [77 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %% [markdown]
# ## Basic Filters

# %%
#Select one column
df['mfr']
# Out:
# 0     N
# 1     Q
# 2     K
# 3     K
# 4     R
#      ..
# 72    G
# 73    G
# 74    R
# 75    G
# 76    G
# Name: mfr, Length: 77, dtype: object

# %%
#Multiple Columns
df[['mfr','name']]
# Out:
#    mfr                       name
# 0    N                  100% Bran
# 1    Q          100% Natural Bran
# 2    K                   All-Bran
# 3    K  All-Bran with Extra Fiber
# 4    R             Almond Delight
# ..  ..                        ...
# 72   G                    Triples
# 73   G                       Trix
# 74   R                 Wheat Chex
# 75   G                   Wheaties
# 76   G        Wheaties Honey Gold
#
# [77 rows x 2 columns]

# %%
# Use loc and iloc
#iloc is used to locate indexes. Slice rows, Slice Columns [select columns]
df.iloc[0:10, 0:12][['mfr','name','calories']]
# Out:
#   mfr                       name  calories
# 0   N                  100% Bran        70
# 1   Q          100% Natural Bran       120
# 2   K                   All-Bran        70
# 3   K  All-Bran with Extra Fiber        50
# 4   R             Almond Delight       110
# 5   G    Apple Cinnamon Cheerios       110
# 6   K                Apple Jacks       110
# 7   G                    Basic 4       130
# 8   R                  Bran Chex        90
# 9   P                Bran Flakes        90

# %%
#I can pass specific columns if I don't want to slice
df.iloc[0:10,[0,3,5,7]]
# Out:
#                         name  calories  fat  fiber
# 0                  100% Bran        70    1   10.0
# 1          100% Natural Bran       120    5    2.0
# 2                   All-Bran        70    1    9.0
# 3  All-Bran with Extra Fiber        50    0   14.0
# 4             Almond Delight       110    2    1.0
# 5    Apple Cinnamon Cheerios       110    2    1.5
# 6                Apple Jacks       110    0    1.0
# 7                    Basic 4       130    2    2.0
# 8                  Bran Chex        90    1    4.0
# 9                Bran Flakes        90    0    5.0

# %%
#loc is used to take index names or column names. Note in this example the index names are just normal index.
df.loc[0:10,["name","calories"]]
# Out:
#                          name  calories
# 0                   100% Bran        70
# 1           100% Natural Bran       120
# 2                    All-Bran        70
# 3   All-Bran with Extra Fiber        50
# 4              Almond Delight       110
# 5     Apple Cinnamon Cheerios       110
# 6                 Apple Jacks       110
# 7                     Basic 4       130
# 8                   Bran Chex        90
# 9                 Bran Flakes        90
# 10               Cap'n'Crunch       120

# %%
#Filter data: If I only use the condition, it will bring a boolean. I can use .sum() at the end to bring to toal
df['mfr'] == 'K'
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Name: mfr, Length: 77, dtype: bool

# %%
#to filter all the table, or part of the columns I can use
df[df['mfr'] == 'K'][['name','type','calories','shelf']] # leave the square brakets if I want the whole table
df[df['mfr'] == 'K']
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 16                  Corn Flakes   K    C       100        2    0     290
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 25               Frosted Flakes   K    C       110        1    0     200
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# 28                Fruitful Bran   K    C       120        3    0     240
# 38  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 39       Just Right Fruit & Nut   K    C       140        3    1     170
# 46         Mueslix Crispy Blend   K    C       160        3    2     150
# 48             Nut&Honey Crunch   K    C       120        2    1     190
# 49    Nutri-Grain Almond-Raisin   K    C       140        3    2     220
# 50            Nutri-grain Wheat   K    C        90        3    0     170
# 53                   Product 19   K    C       100        3    0     320
# 58                  Raisin Bran   K    C       120        3    1     210
# 60               Raisin Squares   K    C        90        2    0       0
# 62                Rice Krispies   K    C       110        2    0     290
# 66                       Smacks   K    C       110        2    1      70
# 67                    Special K   K    C       110        6    0     230
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2     9.0    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    14.0    8.0       0     330        25      3    1.00  0.50  93.704912
# 6     1.0   11.0      14      30        25      2    1.00  1.00  33.174094
# 16    1.0   21.0       2      35        25      1    1.00  1.00  45.863324
# 17    1.0   13.0      12      20        25      2    1.00  1.00  35.782791
# 19    4.0   10.0       7     160        25      3    1.00  0.50  40.448772
# 21    1.0   21.0       3      30        25      3    1.00  1.00  46.895644
# 24    1.0   11.0      13      30        25      2    1.00  1.00  32.207582
# 25    1.0   14.0      11      25        25      1    1.00  0.75  31.435973
# 26    3.0   14.0       7     100        25      2    1.00  0.80  58.345141
# 28    5.0   14.0      12     190        25      3    1.33  0.67  41.015492
# 38    1.0   17.0       6      60       100      3    1.00  1.00  36.523683
# 39    2.0   20.0       9      95       100      3    1.30  0.75  36.471512
# 46    3.0   17.0      13     160        25      3    1.50  0.67  30.313351
# 48    0.0   15.0       9      40        25      2    1.00  0.67  29.924285
# 49    3.0   21.0       7     130        25      3    1.33  0.67  40.692320
# 50    3.0   18.0       2      90        25      3    1.00  1.00  59.642837
# 53    1.0   20.0       3      45       100      3    1.00  1.00  41.503540
# 58    5.0   14.0      12     240        25      2    1.33  0.75  39.259197
# 60    2.0   15.0       6     110        25      3    1.00  0.50  55.333142
# 62    0.0   22.0       3      35        25      1    1.00  1.00  40.560159
# 66    1.0    9.0      15      40        25      2    1.00  0.75  31.230054
# 67    1.0   16.0       3      55        25      1    1.00  1.00  53.131324

# %%
#Filter more than 1 condition
df[(df['mfr'] == 'N') & (df['type'] == 'C') | (df['type'] == 'H')]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 43                      Maypo   A    H       100        4    1       0    0.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 43   16.0       3      95        25      2    1.00  1.00  54.850917
# 57   -1.0      -1     110         0      1    1.00  0.67  50.828392
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %%
#I can use the ~ sign to negate expressions
df[~(df['mfr'].isin(['N','K','Q','R','G']) )]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 9                              Bran Flakes   P    C        90        3    0
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 29                          Fruity Pebbles   P    C       110        1    1
# 30                            Golden Crisp   P    C       100        2    0
# 32                       Grape Nuts Flakes   P    C       100        3    1
# 33                              Grape-Nuts   P    C       110        3    0
# 34                      Great Grains Pecan   P    C       120        3    3
# 37                              Honey-comb   P    C       110        1    0
# 43                                   Maypo   A    H       100        4    1
# 52                   Post Nat. Raisin Bran   P    C       120        3    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 9      210    5.0   13.0       5     190        25      3    1.00  0.67
# 27     160    5.0   12.0      10     200        25      3    1.25  0.67
# 29     135    0.0   13.0      12      25        25      2    1.00  0.75
# 30      45    0.0   11.0      15      40        25      1    1.00  0.88
# 32     140    3.0   15.0       5      85        25      3    1.00  0.88
# 33     170    3.0   17.0       3      90        25      3    1.00  0.25
# 34      75    3.0   13.0       4     100        25      3    1.00  0.33
# 37     180    0.0   14.0      11      35        25      1    1.00  1.33
# 43       0    0.0   16.0       3      95        25      2    1.00  1.00
# 52     200    6.0   11.0      14     260        25      3    1.33  0.67
#
#        rating
# 9   53.313813
# 27  40.917047
# 29  28.025765
# 30  35.252444
# 32  52.076897
# 33  53.371007
# 34  45.811716
# 37  28.742414
# 43  54.850917
# 52  37.840594

# %%
#Same concept of filter can be done using query
df.query("shelf >= 2  and mfr == 'K'")
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# 28                Fruitful Bran   K    C       120        3    0     240
# 38  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 39       Just Right Fruit & Nut   K    C       140        3    1     170
# 46         Mueslix Crispy Blend   K    C       160        3    2     150
# 48             Nut&Honey Crunch   K    C       120        2    1     190
# 49    Nutri-Grain Almond-Raisin   K    C       140        3    2     220
# 50            Nutri-grain Wheat   K    C        90        3    0     170
# 53                   Product 19   K    C       100        3    0     320
# 58                  Raisin Bran   K    C       120        3    1     210
# 60               Raisin Squares   K    C        90        2    0       0
# 66                       Smacks   K    C       110        2    1      70
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2     9.0    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    14.0    8.0       0     330        25      3    1.00  0.50  93.704912
# 6     1.0   11.0      14      30        25      2    1.00  1.00  33.174094
# 17    1.0   13.0      12      20        25      2    1.00  1.00  35.782791
# 19    4.0   10.0       7     160        25      3    1.00  0.50  40.448772
# 21    1.0   21.0       3      30        25      3    1.00  1.00  46.895644
# 24    1.0   11.0      13      30        25      2    1.00  1.00  32.207582
# 26    3.0   14.0       7     100        25      2    1.00  0.80  58.345141
# 28    5.0   14.0      12     190        25      3    1.33  0.67  41.015492
# 38    1.0   17.0       6      60       100      3    1.00  1.00  36.523683
# 39    2.0   20.0       9      95       100      3    1.30  0.75  36.471512
# 46    3.0   17.0      13     160        25      3    1.50  0.67  30.313351
# 48    0.0   15.0       9      40        25      2    1.00  0.67  29.924285
# 49    3.0   21.0       7     130        25      3    1.33  0.67  40.692320
# 50    3.0   18.0       2      90        25      3    1.00  1.00  59.642837
# 53    1.0   20.0       3      45       100      3    1.00  1.00  41.503540
# 58    5.0   14.0      12     240        25      2    1.33  0.75  39.259197
# 60    2.0   15.0       6     110        25      3    1.00  0.50  55.333142
# 66    1.0    9.0      15      40        25      2    1.00  0.75  31.230054

# %% [markdown]
# ## Grouping

# %%
#This will show only a place in memory
df.groupby('mfr')

# %%
df.groupby('mfr').mean('rating')['rating']
# Out:
# mfr
# A    54.850917
# G    34.485852
# K    44.038462
# N    67.968567
# P    41.705744
# Q    42.915990
# R    41.542997
# Name: rating, dtype: float64

# %%
df.groupby(['mfr','type']).sum('calories')[['calories','rating']]
# Out:
#           calories       rating
# mfr type
# A   H          100    54.850917
# G   C         2450   758.688737
# K   C         2500  1012.884634
# N   C          420   343.277587
#     H          100    64.533816
# P   C          980   375.351697
# Q   C          660   292.499527
#     H          100    50.828392
# R   C          920   332.343977

# %%
df.groupby('mfr')[['calories','rating']].mean()
# Out:
#        calories     rating
# mfr
# A    100.000000  54.850917
# G    111.363636  34.485852
# K    108.695652  44.038462
# N     86.666667  67.968567
# P    108.888889  41.705744
# Q     95.000000  42.915990
# R    115.000000  41.542997

# %%
df.groupby('mfr').mean('rating')[['calories','rating']]
# Out:
#        calories     rating
# mfr
# A    100.000000  54.850917
# G    111.363636  34.485852
# K    108.695652  44.038462
# N     86.666667  67.968567
# P    108.888889  41.705744
# Q     95.000000  42.915990
# R    115.000000  41.542997

# %%
df.groupby('mfr')[['calories','rating']].mean().sort_values(by='rating', ascending=False)
# Out:
#        calories     rating
# mfr
# N     86.666667  67.968567
# A    100.000000  54.850917
# K    108.695652  44.038462
# Q     95.000000  42.915990
# P    108.888889  41.705744
# R    115.000000  41.542997
# G    111.363636  34.485852

# %%
df.groupby('mfr')['calories'].describe()
# Out:
#      count        mean        std    min    25%    50%    75%    max
# mfr
# A      1.0  100.000000        NaN  100.0  100.0  100.0  100.0  100.0
# G     22.0  111.363636  10.371873  100.0  110.0  110.0  110.0  140.0
# K     23.0  108.695652  22.218818   50.0  100.0  110.0  115.0  160.0
# N      6.0   86.666667  10.327956   70.0   82.5   90.0   90.0  100.0
# P      9.0  108.888889  10.540926   90.0  100.0  110.0  120.0  120.0
# Q      8.0   95.000000  29.277002   50.0   87.5  100.0  120.0  120.0
# R      8.0  115.000000  22.677868   90.0  100.0  110.0  120.0  150.0

# %%
df['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
# Normalize will give me the percentage of each value. I can than use round to round the number and display only 2 decimal places.
df['mfr'].value_counts( normalize=True).mul(100).round(2)
# Out:
# mfr
# K    29.87
# G    28.57
# P    11.69
# R    10.39
# Q    10.39
# N     7.79
# A     1.30
# Name: proportion, dtype: float64

# %%
#I can also use bins as parameter to create specific groups
df['rating'].value_counts(bins=10, normalize=True).sort_index()
# Out:
# (17.965999999999998, 25.609]    0.077922
# (25.609, 33.175]                0.181818
# (33.175, 40.741]                0.285714
# (40.741, 48.308]                0.142857
# (48.308, 55.874]                0.155844
# (55.874, 63.44]                 0.077922
# (63.44, 71.006]                 0.038961
# (71.006, 78.572]                0.025974
# (78.572, 86.139]                0.000000
# (86.139, 93.705]                0.012987
# Name: proportion, dtype: float64

# %% [markdown]
# ## Eliminating Non Used Data

# %%
# During EDA, I could see -1 where no values where found. As I only have 3 columns with this issue, I can remove them.
df_cleaned = df[~ ((df['carbo'] == -1 ) | (df['sugars'] == -1) | (df['potass'] == -1))]
df_cleaned
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 5    10.5      10      70        25      1     1.0  0.75  29.509541
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [74 rows x 16 columns]

# %%
#Export data if needed.

df_cleaned.to_csv('../Data/Cereal_Cleaned.csv', index=False)

# %% [markdown]
# ## Including New Columns

# %%
df_cleaned['total carbs'] = df_cleaned['carbo'] + df_cleaned['sugars']
df_cleaned.head()
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_4516\3178713306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['total carbs'] = df_cleaned['carbo'] + df_cleaned['sugars']
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 5   10.5      10      70        25      1     1.0  0.75  29.509541
#
#    total carbs
# 0         11.0
# 1         16.0
# 2         12.0
# 3          8.0
# 5         20.5

# %%
df_cleaned['weight_grams'] = df_cleaned['weight'] * 28.3495
# Out:
# C:\Users\satos\AppData\Local\Temp\ipykernel_4516\2451717703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['weight_grams'] = df_cleaned['weight'] * 28.3495

# %%
df_cleaned
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 5     Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 5    10.5      10      70        25      1     1.0  0.75  29.509541
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     total carbs  weight_grams
# 0          11.0       28.3495
# 1          16.0       28.3495
# 2          12.0       28.3495
# 3           8.0       28.3495
# 5          20.5       28.3495
# ..          ...           ...
# 72         24.0       28.3495
# 73         25.0       28.3495
# 74         20.0       28.3495
# 75         20.0       28.3495
# 76         24.0       28.3495
#
# [74 rows x 18 columns]

# %%
with pd.option_context('float_format', '{:.2f}'.format):
    print(df_cleaned.describe())
# Out:
#        calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# count     74.00    74.00 74.00   74.00  74.00  74.00   74.00   74.00
# mean     107.03     2.51  1.00  162.36   2.18  14.73    7.11   98.51
# std       19.84     1.08  1.01   82.77   2.42   3.89    4.36   70.88
# min       50.00     1.00  0.00    0.00   0.00   5.00    0.00   15.00
# 25%      100.00     2.00  0.00  135.00   0.25  12.00    3.00   41.25
# 50%      110.00     2.50  1.00  180.00   2.00  14.50    7.00   90.00
# 75%      110.00     3.00  1.00  217.50   3.00  17.00   11.00  120.00
# max      160.00     6.00  5.00  320.00  14.00  23.00   15.00  330.00
#
#        vitamins  shelf  weight  cups  rating  total carbs  weight_grams
# count     74.00  74.00   74.00 74.00   74.00        74.00         74.00
# mean      29.05   2.22    1.03  0.82   42.37        21.84         29.22
# std       22.29   0.83    0.15  0.24   14.03         4.34          4.35
# min        0.00   1.00    0.50  0.25   18.04         8.00         14.17
# 25%       25.00   1.25    1.00  0.67   32.45        20.00         28.35
# 50%       25.00   2.00    1.00  0.75   40.25        23.00         28.35
# 75%       25.00   3.00    1.00  1.00   50.52        25.00         28.35
# max      100.00   3.00    1.50  1.50   93.70        30.00         42.52

# %% [markdown]
# ## Charts with Pandas - Basics

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 76
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          74 non-null     object
#  1   mfr           74 non-null     object
#  2   type          74 non-null     object
#  3   calories      74 non-null     int64
#  4   protein       74 non-null     int64
#  5   fat           74 non-null     int64
#  6   sodium        74 non-null     int64
#  7   fiber         74 non-null     float64
#  8   carbo         74 non-null     float64
#  9   sugars        74 non-null     int64
#  10  potass        74 non-null     int64
#  11  vitamins      74 non-null     int64
#  12  shelf         74 non-null     int64
#  13  weight        74 non-null     float64
#  14  cups          74 non-null     float64
#  15  rating        74 non-null     float64
#  16  total carbs   74 non-null     float64
#  17  weight_grams  74 non-null     float64
# dtypes: float64(7), int64(8), object(3)
# memory usage: 11.0+ KB

# %%
df_cleaned['mfr'].value_counts().plot(
    kind='bar',
    xlabel='Manufacturer',
    ylabel='Quantity',
    title='Number of cereals by manufacturer'    
    
)
# Out:
# <Axes: title={'center': 'Number of cereals by manufacturer'}, xlabel='Manufacturer', ylabel='Quantity'>

# %%
df_cleaned['mfr'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    title='Share of cereals by manufacturer'
)
# Out:
# <Axes: title={'center': 'Share of cereals by manufacturer'}, ylabel='count'>

# %%
df_cleaned.groupby('mfr')['calories'].mean().plot(
    kind='line',
    xlabel='Manufacturer',
    ylabel='calories',
)
# Out:
# <Axes: xlabel='Manufacturer', ylabel='calories'>

# %% [markdown]
# ## Reshape

# %%
df.groupby(['mfr','shelf']).size().plot(kind='bar')
# Out:
# <Axes: xlabel='mfr,shelf'>

# %%
df.groupby(['mfr','shelf']).size().unstack(level=1).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='mfr'>

# %%
df_pivot = df.pivot_table(
    index='mfr',
    columns='shelf',
    aggfunc='size'
).plot(kind='bar', stacked=True)

# %%
df.unp
